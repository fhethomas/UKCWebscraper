# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import urllib
from os import path
import pandas as pd
import time
import pickle
driver=webdriver.Chrome('../chromedriver.exe')

# %%
amount_of_routes = 1000
climbing_dic = {'name':{},'grade':{},'completed':{},'location_1':{},'location_2':{}}
error_log=[]

# %%
# code will loop through all possible climbs by webpage#
# outputs: name, grade, count of times climbed, regional location, sublocation

def web_scrape(climbing_dic,error_log,amount_of_routes,start_point=1):
    base_location='https://www.ukclimbing.com/logbook/c.php?i='
    for i in range(start_point,amount_of_routes):
        page_location = '{0}{1}'.format(base_location,i)
        driver.get(page_location)
        try:
            el=driver.find_element_by_xpath("//small")
            el1=driver.find_element_by_xpath("//div[@class='progress-bar bg-success polltype1']")
            title=el1.get_property('title')
            climb_name = driver.title
            climb_name = climb_name[climb_name.find('-')+2:]
            climb_grade=el.text
            climb_completed=int(title[title.find('of')+3:title.find('votes')-1])
            location_1=driver.find_element_by_xpath("//li[@class='breadcrumb-item d-none d-sm-inline-block']")
            location_1 = location_1.text
            location_2 = driver.find_elements_by_xpath("//li[@class='breadcrumb-item']")[1].text
            climbing_dic['name'][i]=climb_name
            climbing_dic['grade'][i]=climb_grade
            climbing_dic['completed'][i]=climb_completed
            climbing_dic['location_1'][i]=location_1
            climbing_dic['location_2'][i]=location_2
            climb_style=driver.find_elements_by_xpath("//div[@class='col-4 tiny text-right text-success']")
            climb_style_completed=driver.find_elements_by_xpath("//div[@class='card-body'][1]//div[@class='progress']//div[@class='progress-bar bg-success']")
            # adds all the potential styles that a climb could be done in
            for counter, style in enumerate(climb_style):
                if style.text not in climbing_dic.keys():
                    climbing_dic[style.text]={}
                climbing_dic[style.text][i]=float(climb_style_completed[counter].get_attribute('aria-valuenow'))
        except:
            error_log.append(i)
    # pickle dictionary for later use
    pickle_file = open('climbingdic.pkl','wb')
    pickle.dump(climbing_dic,pickle_file)
    print('errored pages: {0}'.format(len(error_log)))
    print('Records scraped: {0}'.format(len(climbing_dic['name'])))

# %%
web_scrape(climbing_dic=climbing_dic,error_log=error_log,amount_of_routes=amount_of_routes,start_point=len(climbing_dic['name']))
# Out:
# errored pages: 58
# Records scraped: 942

# %%
pd.DataFrame(climbing_dic)
# Out:
#      Alt Leads  Bouldered  DWS  Flashed (β)  Ground Up       Lead  Onsighted  \
# 1    61.781076        NaN  NaN     1.484230   0.371058  13.172542  45.454545
# 2    56.250000        NaN  NaN          NaN        NaN  25.000000  75.000000
# 3     8.906883   0.404858  NaN          NaN        NaN   7.287449  29.959514
# 4          NaN        NaN  NaN          NaN        NaN        NaN        NaN
# 5    54.054054        NaN  NaN     2.702703        NaN  18.918919  54.054054
# 6    65.000000        NaN  NaN          NaN        NaN  15.000000  35.000000
# 7          NaN   7.142857  NaN     7.142857        NaN  21.428571  71.428571
# 8          NaN   5.000000  NaN     7.500000   2.500000  42.500000  52.500000
# 9          NaN   0.473934  NaN     3.317536   0.473934  57.819905  43.601896
# 10         NaN   4.761905  NaN     4.761905        NaN  28.571429  76.190476
# 11         NaN        NaN  NaN     3.809524        NaN  52.380952  43.809524
# 12    0.921659        NaN  NaN     2.534562   0.230415  47.465438  35.023041
# 13         NaN        NaN  NaN    15.625000        NaN  65.625000  62.500000
# 14         NaN        NaN  NaN     5.882353        NaN  47.058824  47.058824
#
#       Redpoint   Repeated     Soloed  completed   grade       location_1  \
# 1     0.371058   2.597403   0.371058         98   E1 5b   Orkney Islands
# 2          NaN        NaN        NaN          8   E3 5c   Orkney Islands
# 3          NaN   2.429150  55.465587         31      VD            Arran
# 4          NaN        NaN        NaN          0  HVS 5a            Arran
# 5          NaN        NaN  10.810811         12       S            Arran
# 6          NaN        NaN        NaN          7   VS 4b            Arran
# 7          NaN  14.285714  64.285714          2   E3 5c  North Yorkshire
# 8     5.000000   5.000000  30.000000          4  HVS 5b  North Yorkshire
# 9     0.473934   7.109005   5.213270         20   VS 5a  North Yorkshire
# 10         NaN        NaN  42.857143          2  HVS 5b  North Yorkshire
# 11         NaN   7.619048   9.523810          8   VS 5a  North Yorkshire
# 12    0.691244  12.903226  15.668203         49     HVD  North Yorkshire
# 13         NaN   9.375000   6.250000          3   E1 5b  North Yorkshire
# 14         NaN        NaN  20.588235          1  HVS 5b  North Yorkshire
# 15         NaN        NaN        NaN          1   E2 5c  North Yorkshire
# 16         NaN        NaN  12.500000          2   E2 5c  North Yorkshire
# 17         NaN   6.854839  10.887097         13   VS 4c  North Yorkshire
# 18   11.475410   9.016393  40.163934          9  HVS 6a  North Yorkshire
# 19         NaN        NaN        NaN          1   E2 5b  North Yorkshire
# 20    1.255230   9.121339   4.351464         52   HS 4b  North Yorkshire
# 21    5.109489   5.839416   2.919708         23   E3 5b  North Yorkshire
# 22   27.777778        NaN  11.111111          2   E4 6a  North Yorkshire
# 23         NaN        NaN        NaN          0   E5 6c  North Yorkshire
# 24    1.038576  12.314540  11.275964         38    S 4b  North Yorkshire
# 25    0.420905  20.624342  15.994388        211  HVD 3c  North Yorkshire
# 26    0.421644  16.936051  13.633169        109    S 4a  North Yorkshire
# 27    0.458716  21.100917  22.935780         13    S 4a  North Yorkshire
# 28    0.367261  20.199370  33.892970        115       D  North Yorkshire
# 29    0.499064  21.584529  21.522146         92     HVD  North Yorkshire
# 30    2.083333   2.083333  18.750000          7   E2 5c  North Yorkshire
# ..         ...        ...        ...        ...     ...              ...
# 970        NaN   1.190476  42.261905          0       D   Northumberland
# 971   1.025641   6.666667  28.205128         46    S 4c   Northumberland
# 972        NaN   3.125000   9.375000         11  HVS 5b   Northumberland
# 973  14.285714        NaN  14.285714          1   E2 5c   Northumberland
# 974   0.240964  13.413655  21.927711         98     HVD   Northumberland
# 975        NaN        NaN  28.571429          0   E3 6a   Northumberland
# 976        NaN        NaN  27.272727          0   E1 5b   Northumberland
# 977        NaN   4.000000  40.000000          4   E1 5c   Northumberland
# 978        NaN   5.309735  27.433628         13  HVS 5a   Northumberland
# 979        NaN        NaN  33.333333          1   E2 5c   Northumberland
# 980   0.836820   4.184100  31.380753         16    S 4b   Northumberland
# 981        NaN   6.666667  43.333333          3   VS 5a   Northumberland
# 982   3.278689   1.639344  31.147541          4   VS 5a   Northumberland
# 983   2.380952   6.547619  13.690476         22   E1 5c   Northumberland
# 984   1.650619  10.178817  19.257221        112   VS 5a   Northumberland
# 985  10.526316   2.631579  42.105263          7   E2 5c   Northumberland
# 986        NaN        NaN        NaN          1   E2 6c   Northumberland
# 987   3.030303   3.030303   9.090909          8   E1 5b   Northumberland
# 988        NaN        NaN        NaN          0   E4 6b   Northumberland
# 989   7.142857        NaN  21.428571          5   E5 6b   Northumberland
# 990        NaN   9.090909  18.181818          1   E2 5c   Northumberland
# 991   1.443001  11.111111  15.873016        105  HVS 5a   Northumberland
# 992        NaN   9.523810  52.380952          4   E2 5b   Northumberland
# 993   2.597403   2.597403  16.883117          6   HS 4c   Northumberland
# 994   0.334448   5.016722  18.394649         36      VD   Northumberland
# 995        NaN   2.197802  30.769231          7  HVS 5a   Northumberland
# 996   2.158273   6.474820  66.187050         17   E1 5c   Northumberland
# 997   0.182482   9.306569  28.102190         60   VS 4c   Northumberland
# 998   0.303951   8.510638  16.413374         61   VS 5a   Northumberland
# 999   3.448276        NaN  13.793103          6   E2 5c   Northumberland
#
#     location_2                                name
# 1     Logbooks  'East Face Route (Original Route)'
# 2     Logbooks                'A Few Dollars More'
# 3     Logbooks                      'A'Chir Ridge'
# 4     Logbooks                           'Minaret'
# 5     Logbooks                      'Pagoda Ridge'
# 6     Logbooks                            'Mosque'
# 7     Logbooks                    'Envy of Angels'
# 8     Logbooks                   'Angelic Upstart'
# 9     Logbooks            'Pram Pusher's Paradise'
# 10    Logbooks     'A Step in the Right Direction'
# 11    Logbooks                  'V Chimney Direct'
# 12    Logbooks            'V Chimney and Traverse'
# 13    Logbooks                      'Up Periscope'
# 14    Logbooks                     'Depth Charger'
# 15    Logbooks                           'Trident'
# 16    Logbooks                           'Torpedo'
# 17    Logbooks                   'Pigott's Stride'
# 18    Logbooks                           'V Crack'
# 19    Logbooks                      'Spirit Level'
# 20    Logbooks     'Square Chimney & Whisky Crack'
# 21    Logbooks                       'Whisky Wall'
# 22    Logbooks                'Whisky Wall Direct'
# 23    Logbooks                   'Wharfedale Wall'
# 24    Logbooks                      'Fluted Crack'
# 25    Logbooks                    'Fluted Columns'
# 26    Logbooks              'Pinnacle Flake Climb'
# 27    Logbooks                   'Pinnacle Direct'
# 28    Logbooks                  'Low Man Easy Way'
# 29    Logbooks                          'Stew Pot'
# 30    Logbooks                 'Yorkshire Pudding'
# ..         ...                                 ...
# 970   Logbooks                        'Flake Wall'
# 971   Logbooks                               'Sue'
# 972   Logbooks                        'Sue Direct'
# 973   Logbooks                             'Bella'
# 974   Logbooks                      'Castle Crack'
# 975   Logbooks              'The Belford Pie Shop'
# 976   Logbooks                          'The Keep'
# 977   Logbooks                'Picher Wall Direct'
# 978   Logbooks                      'Pitcher Wall'
# 979   Logbooks                         'Pitchfork'
# 980   Logbooks                     'Crescent Wall'
# 981   Logbooks               'Pride Before a Fall'
# 982   Logbooks                              'Runt'
# 983   Logbooks                'Little Red Rooster'
# 984   Logbooks                          'Lorraine'
# 985   Logbooks                      'Don't Let Go'
# 986   Logbooks         'Don't Let Go Direct Start'
# 987   Logbooks                        'Slab Crack'
# 988   Logbooks                           'Imagery'
# 989   Logbooks                         'The Rajah'
# 990   Logbooks                       'The Cheetah'
# 991   Logbooks                      'Tiger's Wall'
# 992   Logbooks                               'Leo'
# 993   Logbooks                         'Red Crack'
# 994   Logbooks                       'Black Crack'
# 995   Logbooks                     'Banana Groove'
# 996   Logbooks                           'Abanana'
# 997   Logbooks                       'Banana Wall'
# 998   Logbooks                        'The Runnel'
# 999   Logbooks                      'Yellow Peril'
#
# [942 rows x 15 columns]
